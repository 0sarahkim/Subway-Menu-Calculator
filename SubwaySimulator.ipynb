# %%
class subway():
        def __init__(self, max_capacity):
            self.max_capacity = max_capacity
            self.queue_inside = []
            self.queue_outside = []
            self.data = 0
        
        def get_data(self):
            import pandas as pd
            import numpy as np
            self.data=pd.read_csv('C:/Users/Sarah/Desktop/Advanced Python/Diet-Tracker/subway.csv',index_col=None,skip_blank_lines=True)
        
        def enter(self, name):
            if len(self.queue_inside) < self.max_capacity:
                print(f'Hello {name}, Thank you for coming!')
                self.queue_inside.append(name)
            else:
                res = input(f'Hello {name}, We are currently out of capacity, can you wait at the outside? Y/N')
                if res == 'Y':
                    self.queue_outside.append(name)
                elif res == 'N':
                    print('OK, see you next time!')
                else:
                    print('You chose invalid response')
            
        def order(self):
            import pandas as pd
            import numpy as np
            if len(self.queue_inside) != 0:
                name = self.queue_inside.pop(0)
                print(f'What do you want to have {name} ?')
                print("CHOOSE:\n 1. Sandwich\n 2. Salad\n 3. Wrap\n 4. Cookie")
                category = input("Enter Number: ")
                category = int(category)
                total_order = []
                ordered_category = 0 

                if category == 1 :
                    ordered_category = 'Sandwich'
                    print("\n<Which Sandwich do you want?>\n")
                    print("=====Here's the Menu=====\n\n")
                    print("------------------------------\n",
                      "- BBQ Rib\n",
                        "- Black Forest Ham\n",
                        "- Chicken & Bacon Ranch Melt\n",
                        "- Chicken Mango Curry\n",
                        "- Chicken Tikka\n",
                        "- Chicken Vindaloo\n",
                        "- Classic Tuna\n",
                        "- Cold Cut Combo\n",
                        "- Genoa Salami\n",
                        "- Italian B.M.T.Â®\n",
                        "- Meatball Marinara\n",
                        "- Ham & Jack Slider\n",
                        "- Italian Spice Slider\n",
                        "- Little Cheesesteak Slider\n",
                        "- Little Turkey Slider\n",
                        "- Southwest Chicken Club\n",
                        "- Steak Club\n",
                        "- Ultimate Steak\n",
                        "- Oven Roasted Chicken\n",
                        "- Paneer Tikka\n",
                        "- Roast Beef\n",
                        "- Rotisserie-Style Chicken\n",
                        "- Spicy Italian\n",
                        "- Steak & Cheese\n",
                        "- Subway ClubÂ®\n",
                        "- Sweet Onion Chicken Teriyaki\n",
                        "- Turkey & Bacon Guacamole\n",
                        "- Turkey Breast\n",
                        "- Ultimate Meatball Marinara\n",
                        "- Ultimate Spicy Italian\n",
                        "- Veggie DeliteÂ®\n",
                      "------------------------------\n")

                    menu = input("Enter your choice of Menu")
                    total_order.append(menu)
                    ## Bread
                    print("What bread do you want?\n")
                    print("------------------------------\n",
                      "- Roasted Garlic\n",
                        "- 9-Grain Honey Oat\n",
                        "- 9-Grain Wheat\n",
                        "- Artisan Flatbread\n",
                        "- Hearty Italian**\n",
                        "- Italian\n",
                        "- Italian Herbs & Cheese\n",
                        "- JalapeÃ±o Cheese\n",
                        "- Mini 9-Grain Wheat\n",
                        "- Mini Italian\n",
                        "- Monterey Cheddar**\n",
                        "- Parmesan Oregano**\n",
                        "- Rosemary & Sea Salt\n",
                      "------------------------------\n")

                    bread_list = self.data[self.data['Category'] == 'Bread' ]['Name'].tolist()
                    x = True
                    while x:
                        bread = input("Enter your choice of Bread")
                        if bread in bread_list:
                            x = False 
                            total_order.append(bread)
                        else: 
                            print("Invalid Input")

                    ## Cheese
                    print("What cheese do you want?")
                    print("------------------------------\n",
                      "- American\n",
                        "- Cheddar**\n",
                        "- Monterey Cheddar\n",
                        "- Pepperjack**\n",
                        "- Provolone\n",
                        "- Shredded Mozzarella\n",
                        "- Swiss**\n",
                      "------------------------------\n")                    
                    cheese_list = self.data[self.data['Category'] == 'Cheese' ]['Name'].tolist()
                    x = True
                    while x:
                        cheese = input("Enter your choice of Cheese")
                        if cheese in cheese_list:
                            x = False 
                            total_order.append(cheese)
                        else: 
                            print("Invalid Input")

                    ## Vegi
                    print("What veggies do you want?\n")
                    print("Choose Your Vegies from Below\n")
                    print("------------------------------\n",
                      "- Banana Peppers\n",
                        "- Black Olives\n",
                        "- Cucumbers\n",
                        "- Green Peppers\n",
                        "- Jalapenos\n",
                        "- Lettuce\n",
                        "- Pickles\n",
                        "- Red Onions\n",
                        "- Spinach\n",
                        "- Tomatoes\n",
                     "------------------------------\n")

                    veggie_list = self.data[self.data['Category'] == 'Veggies' ]['Name'].tolist()
                    x = True
                    while x:
                        vegi = input("Enter your choice of veggie (Choose 1)")
                        if vegi in veggie_list:
                            total_order.append(vegi)
                            more = input("Do you want to add more? Y/N")
                            if more == 'Y':
                                continue
                            elif more == 'N':
                                x = False
                            else:
                                print('You chose wrong response')
                        else: 
                            print("Invalid Input")

                    ## Sauce
                    print("\n What sauces do you want? \n")
                    print("Choose Your Sauce from Below: \n")
                    print("------------------------------\n",
                      "- Chipotle Southwest\n",
                        "- Honey Mustard**\n",
                        "- Light Mayonnaise\n",
                        "- Oil\n",
                        "- Ranch",
                        "- Red Wine Vinegar\n",
                        "- Regular Mayonnaise\n",
                        "- Savory Caesar**\n",
                        "- Spicy Brown Mustard\n",
                        "- SubwayÂ® Vinaigrette\n",
                        "- Sweet Onion Sauce\n",
                        "- Yellow Mustard\n",
                      "------------------------------\n"  )
                    sauce_list = self.data[self.data['Category'] == 'Sauces' ]['Name'].tolist()
                    x = True
                    while x:
                        sauce = input("Enter your choice of sauce (Choose 1)")
                        if sauce in sauce_list:
                            total_order.append(sauce)
                            more = input("Do you want to add more? Y/N")
                            if more == 'Y':
                                continue
                            elif more == 'N':
                                x = False
                            else:
                                print('You chose wrong response')
                        else: 
                            print("Invalid Input")

                if category == 2 :
                    ordered_category = 'Salad'
                    print("\n<Which SALAD do you want?>\n")
                    print("=====Here's the Menu=====\n")
                    print("------------------------------\n",
                      "- BBQ Rib\n",
                        "- Black Forest Ham\n",
                        "- Chicken & Bacon Ranch\n",
                        "- Cold Cut Combo\n",
                        "- Italian B.M.T. Â®\n",
                        "- Meatball Marinara\n",
                        "- Oven Roasted Chicken\n",
                        "- Roast Beef\n",
                        "- Rotisserie-Style Chicken\n",
                        "- Southwest Chipotle Chicken Club\n",
                        "- Spicy Italian\n",
                        "- Steak & Cheese\n",
                        "- Steak Club Salad\n",
                        "- Subway ClubÂ®\n",
                        "- Sweet Onion Chicken Teriyaki\n",
                        "- Tuna\n",
                        "- Turkey Breast\n",
                        "- Veggie DeliteÂ®\n",
                      "------------------------------\n")

                    menu = input("Enter your choice of Salad Menu")
                    total_order.append(menu)

                    ## Cheese
                    print("What cheese do you want?")
                    print("------------------------------\n",
                      "- American\n",
                        "- Cheddar**\n",
                        "- Monterey Cheddar\n",
                        "- Pepperjack**\n",
                        "- Provolone\n",
                        "- Shredded Mozzarella\n",
                        "- Swiss**\n",
                      "------------------------------\n")                    
                    cheese_list = self.data[self.data['Category'] == 'Cheese' ]['Name'].tolist()
                    x = True
                    while x:
                        cheese = input("Enter your choice of Cheese")
                        if cheese in cheese_list:
                            x = False 
                            total_order.append(cheese)
                        else: 
                            print("Invalid Input")

                    ## Sauce
                    print("\n What sauces do you want? \n")
                    print("Choose Your Sauce from Below: \n")
                    print("------------------------------\n",
                      "- Chipotle Southwest\n",
                        "- Honey Mustard**\n",
                        "- Light Mayonnaise\n",
                        "- Oil\n",
                        "- Ranch",
                        "- Red Wine Vinegar\n",
                        "- Regular Mayonnaise\n",
                        "- Savory Caesar**\n",
                        "- Spicy Brown Mustard\n",
                        "- SubwayÂ® Vinaigrette\n",
                        "- Sweet Onion Sauce\n",
                        "- Yellow Mustard\n",
                      "------------------------------\n"  )

                    sauce_list = self.data[self.data['Category'] == 'Sauces' ]['Name'].tolist()
                    x = True
                    while x:
                        sauce = input("Enter your choice of sauce (Choose 1)")
                        if sauce in sauce_list:
                            total_order.append(sauce)
                            more = input("Do you want to add more? Y/N")
                            if more == 'Y':
                                continue
                            elif more == 'N':
                                x = False
                            else:
                                print('You chose wrong response')
                        else: 
                            print("Invalid Input")

                if category == 3:
                    ordered_category = 'Wrap'
                    print("\n<Which WRAP do you want?>\n")
                    print("=====Here's the Menu=====\n\n")
                    print("------------------------------\n",
                        "- BBQ Rib Signature Wrap\n",
                        "- Black Forest Ham\n",
                        "- Chicken & Bacon Ranch Melt\n",
                        "- Chipotle Southwest Steak & Cheese\n",
                        "- Cold Cut Combo\n",
                        "- Cripsy Cauliflower Ranch Signature Wrap\n",
                        "- Italian B.M.T. Â®\n",
                        "- Meatball Marinara\n",
                        "- Cauliflower Fritter Curry Signature Wrap\n",
                        "- Oven Roasted Chicken\n",
                        "- Roast Beef\n",
                        "- Rotisserie-Style Chicken\n",
                        "- Savory Rotisserie-Style Chicken Caesar\n",
                        "- Spicy Italian\n",
                        "- Subway ClubÂ®\n",
                        "- Sweet Onion Chicken Teriyaki\n",
                        "- Tuna\n",
                        "- Turkey Breast\n",
                        "- Turkey, Bacon & Guacamole\n",
                        "- Veggie DeliteÂ®\n",
                      "------------------------------\n")

                    menu = input("Enter your choice of Wrap Menu")
                    total_order.append(menu)
                    ## Bread
                    print("What do you want it wrapped in?\n")
                    print("------------------------------\n",
                      "- Spinach Wrap\n","- Tomato Basil Wrap\n",   
                      "------------------------------\n")

                    bread_list = self.data[self.data['Category'] == 'Bread' ]['Name'].tolist()
                    x = True
                    while x:
                        bread = input("Enter your choice of Wrap")
                        if bread in bread_list:
                            x = False 
                            total_order.append(bread)
                        else: 
                            print("Invalid Input")

                    ## Cheese
                    print("What cheese do you want?")
                    print("------------------------------\n",
                        "- American\n",
                        "- Cheddar**\n",
                        "- Monterey Cheddar\n",
                        "- Pepperjack**\n",
                        "- Provolone\n",
                        "- Shredded Mozzarella\n",
                        "- Swiss**\n",
                      "------------------------------\n")                    
                    cheese_list = self.data[self.data['Category'] == 'Cheese' ]['Name'].tolist()
                    x = True
                    while x:
                        cheese = input("Enter your choice of Cheese")
                        if cheese in cheese_list:
                            x = False 
                            total_order.append(cheese)
                        else: 
                            print("Invalid Input")

                    ## Veggie
                    print("What veggies do you want?\n")
                    print("Choose Your Veggies from Below\n")
                    print("------------------------------\n",
                      "- Banana Peppers\n",
                        "- Black Olives\n",
                        "- Cucumbers\n",
                        "- Green Peppers\n",
                        "- Jalapenos\n",
                        "- Lettuce\n",
                        "- Pickles\n",
                        "- Red Onions\n",
                        "- Spinach\n",
                        "- Tomatoes\n",
                     "------------------------------\n")

                    veggie_list = self.data[self.data['Category'] == 'Veggies' ]['Name'].tolist()
                    x = True
                    while x:
                        vegi = input("Enter your choice of veggie (Choose 1)")
                        if vegi in veggie_list:
                            total_order.append(vegi)
                            more = input("Do you want to add more? Y/N")
                            if more == 'Y':
                                continue
                            elif more == 'N':
                                x = False
                            else:
                                print('You chose wrong response')
                        else: 
                            print("Invalid Input")

                    ## Sauce
                    print("\n What sauces do you want? \n")
                    print("Choose Your Sauce from Below: \n")
                    print("------------------------------\n",
                      "- Chipotle Southwest\n",
                        "- Honey Mustard**\n",
                        "- Light Mayonnaise\n",
                        "- Oil\n",
                        "- Ranch",
                        "- Red Wine Vinegar\n",
                        "- Regular Mayonnaise\n",
                        "- Savory Caesar**\n",
                        "- Spicy Brown Mustard\n",
                        "- SubwayÂ® Vinaigrette\n",
                        "- Sweet Onion Sauce\n",
                        "- Yellow Mustard\n",
                      "------------------------------\n"  )

                    sauce_list = self.data[self.data['Category'] == 'Sauces' ]['Name'].tolist()
                    x = True
                    while x:
                        sauce = input("Enter your choice of sauce (Choose 1)")
                        if sauce in sauce_list:
                            total_order.append(sauce)
                            more = input("Do you want to add more? Y/N")
                            if more == 'Y':
                                continue
                            elif more == 'N':
                                x = False
                            else:
                                print('You chose wrong response')
                        else: 
                            print("Invalid Input")

                if category == 4 :
                    ordered_category = 'Extra'
                    print("\n<Which COOKIE do you want?>\n")
                    print("=====Here's the list=====\n\n")
                    print("------------------------------\n",
                        "- Caramel Apple Cookie\n",
                        "- Chocolate Chip Cookie\n",
                        "- Chocolate Chip with M&Mâ€™s Â®\n",
                        "- Chocolate Chunk Cookie\n",
                        "- Dark Chocolate Cherry Cookie\n",
                        "- Double Chocolate\n",
                        "- Oatmeal Raisin Cookie\n",
                        "- Raspberry Cheesecake Cookie\n",
                        "- Raspberry Lemonade Cookie\n",
                        "- Sugar Cookie\n",
                        "- White Chip Macadamia Nut Cookie\n",
                      "------------------------------\n")

                    menu = input("Enter your choice of Cookie")
                    total_order.append(menu)            

                order_dt = pd.DataFrame()
                for i in total_order:
                    tmp = self.data[(self.data['Name'] == i) & ((self.data['Category'] == ordered_category) |
                                                   (self.data['Category'] == 'Bread') |
                                                   (self.data['Category'] == 'Cheese') |
                                                   (self.data['Category'] == 'Veggies') |
                                                   (self.data['Category'] == 'Sauce' ))]
                    order_dt = pd.concat([order_dt,tmp])

                r = order_dt.sum()
                tot_cal = r.iloc[2]
                tot_fat = r.iloc[3]
                tot_sat_fat = r.iloc[4]
                tot_t_fat = r.iloc[5]
                tot_chol = r.iloc[6]
                tot_sod = r.iloc[7]
                tot_carb = r.iloc[8]
                tot_fiber = r.iloc[9]
                tot_sugar = r.iloc[10]
                tot_protein = r.iloc[11]

                print(f'Here is your menu {name}!')
                print(f'''FYI, total nutritional components of your menu are:
                      Calories: {tot_cal},
                      Carbohydrates: {tot_carb},
                      Protein: {tot_protein},
                      Fat: {tot_fat},
                      Saturated Fat: {tot_sat_fat},
                      Trans Fat: {tot_t_fat},
                      Cholesterol: {tot_chol},
                      Dietary Fiber: {tot_fiber},
                      Sugar: {tot_sugar},
                      Sodium: {tot_sod}''')

                print(f'Take care!')

                if (len(self.queue_inside) < self.max_capacity) and (len(self.queue_outside) != 0): 
                    n = self.queue_outside.pop(0)
                    print(f'Thank you for waiting {n}, Come on in!')
                    self.queue_inside.append(n)
            else:
                print('No one in queue')

# %%
# Simulation Example

# %%
t = subway(3)

# %%
t.get_data()

# %%
t.enter('Sarah')
# Out:
# Hello Sarah, Thank you for coming!

# %%
t.enter('Frank')
# Out:
# Hello Johnny, Thank you for coming!

# %%
t.enter('Amy')
# Out:
# Hello Echi, Thank you for coming!

# %%
t.enter('John')
# Out:
# Hello Vegi, We are currently out of capacity, can you wait at the outside? Y/N
# You chose invalid response

# %%
t.order()
# Out:
# No one in queue
