# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime

# %%
data=pd.read_csv('C:/Users/Sarah/Desktop/Advanced Python/Diet-Tracker/subway.csv',index_col=None,skip_blank_lines=True)

# %%
data.head()
# Out:
#                          Name  Category  Calories  Total Fat (g)  \
# 0                     BBQ Rib  Sandwich       580           31.0
# 1            Black Forest Ham  Sandwich       260            4.0
# 2  Chicken & Bacon Ranch Melt  Sandwich       530           26.0
# 3         Chicken Mango Curry  Sandwich       330            7.0
# 4               Chicken Tikka  Sandwich       290            5.0
#
#    Saturated Fat (g)  Trans Fat (g)  Cholesterol (mg)  Sodium (mg)  \
# 0               10.0            0.0                60         1260
# 1                1.5            0.0                30          720
# 2               10.0            0.5               100         1100
# 3                1.5            0.0                50          840
# 4                1.0            0.0                50          720
#
#    Carbohydrates (g)  Dietary Fiber (g)  Sugars (g)  Protein (g)
# 0                 54                  3          18           21
# 1                 42                  5           8           18
# 2                 41                  3           6           36
# 3                 43                  3           9           24
# 4                 39                  2           6           23

# %%
data=data[['Name', 'Category', 'Calories', 'Total Fat (g)',
       'Saturated Fat (g)', 'Trans Fat (g)', 'Cholesterol (mg)', 'Sodium (mg)',
       'Carbohydrates (g)', 'Dietary Fiber (g)', 'Sugars (g)', 'Protein (g)']]

# %%
def calculate():
        print("CHOOSE:\n 1. Sandwich\n 2. Salad\n 3. Wrap\n 4. Snacks")
        category = input("Enter Number: ")
        category = int(category)
    
        if category == 1 :
            total_order = []
            print("\n<Which Sandwich do you want?>\n")
            print("=====Here's the Menu=====\n\n")
            print("------------------------------\n",
                  "- BBQ Rib\n",
                    "- Black Forest Ham\n",
                    "- Chicken & Bacon Ranch Melt\n",
                    "- Chicken Mango Curry\n",
                    "- Chicken Tikka\n",
                    "- Chicken Vindaloo\n",
                    "- Classic Tuna\n",
                    "- Cold Cut Combo\n",
                    "- Genoa Salami\n",
                    "- Italian B.M.T.Â®\n",
                    "- Meatball Marinara\n",
                    "- Ham & Jack Slider\n",
                    "- Italian Spice Slider\n",
                    "- Little Cheesesteak Slider\n",
                    "- Little Turkey Slider\n",
                    "- Southwest Chicken Club\n",
                    "- Steak Club\n",
                    "- Ultimate Steak\n",
                    "- Oven Roasted Chicken\n",
                    "- Paneer Tikka\n",
                    "- Roast Beef\n",
                    "- Rotisserie-Style Chicken\n",
                    "- Spicy Italian\n",
                    "- Steak & Cheese\n",
                    "- Subway ClubÂ®\n",
                    "- Sweet Onion Chicken Teriyaki\n",
                    "- Turkey & Bacon Guacamole\n",
                    "- Turkey Breast\n",
                    "- Ultimate Meatball Marinara\n",
                    "- Ultimate Spicy Italian\n",
                    "- Veggie DeliteÂ®\n",
                  "------------------------------\n")
            
            menu = input("Enter your choice of Menu")
            total_order.append(menu)
            ## Bread
            print("What bread do you want?\n")
            print("------------------------------\n",
                  "- Roasted Garlic\n",
                    "- 9-Grain Honey Oat\n",
                    "- 9-Grain Wheat\n",
                    "- Artisan Flatbread\n",
                    "- Hearty Italian**\n",
                    "- Italian\n",
                    "- Italian Herbs & Cheese\n",
                    "- JalapeÃ±o Cheese\n",
                    "- Mini 9-Grain Wheat\n",
                    "- Mini Italian\n",
                    "- Monterey Cheddar**\n",
                    "- Parmesan Oregano**\n",
                    "- Rosemary & Sea Salt\n",
                  "------------------------------\n")
            
            bread_list = data[data['Category'] == 'Bread' ]['Name'].tolist()
            x = True
            while x:
                bread = input("Enter your choice of Bread")
                if bread in bread_list:
                    x = False 
                    total_order.append(bread)
                else: 
                    print("Invalid Input")
                        
            ## Cheese
            print("What cheese do you want?")
            print("------------------------------\n",
                  "- American\n",
                    "- Cheddar**\n",
                    "- Monterey Cheddar\n",
                    "- Pepperjack**\n",
                    "- Provolone\n",
                    "- Shredded Mozzarella\n",
                    "- Swiss**\n",
                  "------------------------------\n")                    
            cheese_list = data[data['Category'] == 'Cheese' ]['Name'].tolist()
            x = True
            while x:
                cheese = input("Enter your choice of Cheese")
                if cheese in cheese_list:
                    x = False 
                    total_order.append(cheese)
                else: 
                    print("Invalid Input")
                        
            ## Vegi
            print("What veggies do you want?\n")
            print("Choose Your Vegies from Below\n")
            print("------------------------------\n",
                  "- Banana Peppers\n",
                    "- Black Olives\n",
                    "- Cucumbers\n",
                    "- Green Peppers\n",
                    "- Jalapenos\n",
                    "- Lettuce\n",
                    "- Pickles\n",
                    "- Red Onions\n",
                    "- Spinach\n",
                    "- Tomatoes\n",
                 "------------------------------\n")
            
            veggie_list = data[data['Category'] == 'Veggies' ]['Name'].tolist()
            x = True
            while x:
                vegi = input("Enter your choice of veggie (Choose 1)")
                if vegi in veggie_list:
                    total_order.append(vegi)
                    more = input("Do you want to add more? Y/N")
                    if more == 'Y':
                        continue
                    else:
                        x = False
                else: 
                    print("Invalid Input")
                        

            ## Sauce
            print("\n What sauces do you want? \n")
            print("Choose Your Sauce from Below: \n")
            print("------------------------------\n",
                  "- Chipotle Southwest\n",
                    "- Honey Mustard**\n",
                    "- Light Mayonnaise",
                    "- Oil\n",
                    "- Ranch",
                    "- Red Wine Vinegar\n",
                    "- Regular Mayonnaise\n",
                    "- Savory Caesar**\n",
                    "- Spicy Brown Mustard\n",
                    "- SubwayÂ® Vinaigrette\n",
                    "- Sweet Onion Sauce\n",
                    "- Yellow Mustard\n",
                  "------------------------------\n"  )
            sauce_list = data[data['Category'] == 'Sauces' ]['Name'].tolist()
            x = True
            while x:
                sauce = input("Enter your choice of sauce (Choose 1)")
                if sauce in sauce_list:
                    total_order.append(sauce)
                    more = input("Do you want to add more? Y/N")
                    if more == 'Y':
                        continue
                    else:
                        x = False
                else: 
                    print("Invalid Input")
            
    
            order_dt = pd.DataFrame()
            for i in total_order:
                tmp = data[ data['Name'] == i ]
                order_dt = pd.concat([order_dt,tmp])
            
            return order_dt
        
        
        if category == 2 :
            total_order = []
            print("\n<Which WRAP do you want?>\n")
            print("=====Here's the Menu=====\n\n")
            print("------------------------------\n",
                  "BBQ Rib Signature Wrap",
                    "Black Forest Ham",
                    "Chicken & Bacon Ranch Melt",
                    "Chipotle Southwest Steak & Cheese",
                    "Cold Cut Combo",
                    "Cripsy Cauliflower Ranch Signature Wrap",
                    "Italian B.M.T. Â®",
                    "Meatball Marinara",
                    "Cauliflower Fritter Curry Signature Wrap",
                    "Oven Roasted Chicken",
                    "Roast Beef",
                    "Rotisserie-Style Chicken",
                    "Savory Rotisserie-Style Chicken Caesar",
                    "Spicy Italian",
                    "Subway ClubÂ®",
                    "Sweet Onion Chicken Teriyaki",
                    "Tuna",
                    "Turkey Breast",
                    "Turkey, Bacon & Guacamole",
                    "Veggie DeliteÂ®",
                  "------------------------------\n")
            
            menu = input("Enter your choice of Wrap Menu")
            total_order.append(menu)
            ## Bread
            print("What do you want it wrapped in?\n")
            print("------------------------------\n",
                  "Spinach Wrap","Tomato Basil Wrap",   
                  "------------------------------\n")
            
            bread_list = data[data['Category'] == 'Bread' ]['Name'].tolist()
            x = True
            while x:
                bread = input("Enter your choice of Wrap")
                if bread in bread_list:
                    x = False 
                    total_order.append(bread)
                else: 
                    print("Invalid Input")
                        
            ## Cheese
            print("What cheese do you want?")
            print("------------------------------\n",
                  "- American\n",
                    "- Cheddar**\n",
                    "- Monterey Cheddar\n",
                    "- Pepperjack**\n",
                    "- Provolone\n",
                    "- Shredded Mozzarella\n",
                    "- Swiss**\n",
                  "------------------------------\n")                    
            cheese_list = data[data['Category'] == 'Cheese' ]['Name'].tolist()
            x = True
            while x:
                cheese = input("Enter your choice of Cheese")
                if cheese in cheese_list:
                    x = False 
                    total_order.append(cheese)
                else: 
                    print("Invalid Input")
                        
            ## Vegi
            print("What veggies do you want?\n")
            print("Choose Your Veggies from Below\n")
            print("------------------------------\n",
                  "- Banana Peppers\n",
                    "- Black Olives\n",
                    "- Cucumbers\n",
                    "- Green Peppers\n",
                    "- Jalapenos\n",
                    "- Lettuce\n",
                    "- Pickles\n",
                    "- Red Onions\n",
                    "- Spinach\n",
                    "- Tomatoes\n",
                 "------------------------------\n")
            
            veggie_list = data[data['Category'] == 'Veggies' ]['Name'].tolist()
            x = True
            while x:
                vegi = input("Enter your choice of veggie (Choose 1)")
                if vegi in veggie_list:
                    total_order.append(vegi)
                    more = input("Do you want to add more? Y/N")
                    if more == 'Y':
                        continue
                    else:
                        x = False
                else: 
                    print("Invalid Input")
                        

            ## Sauce
            print("\n What sauces do you want? \n")
            print("Choose Your Sauce from Below: \n")
            print("------------------------------\n",
                  "- Chipotle Southwest\n",
                    "- Honey Mustard**\n",
                    "- Light Mayonnaise",
                    "- Oil\n",
                    "- Ranch",
                    "- Red Wine Vinegar\n",
                    "- Regular Mayonnaise\n",
                    "- Savory Caesar**\n",
                    "- Spicy Brown Mustard\n",
                    "- SubwayÂ® Vinaigrette\n",
                    "- Sweet Onion Sauce\n",
                    "- Yellow Mustard\n",
                  "------------------------------\n"  )
            sauce_list = data[data['Category'] == 'Sauces' ]['Name'].tolist()
            x = True
            while x:
                sauce = input("Enter your choice of sauce (Choose 1)")
                if sauce in sauce_list:
                    total_order.append(sauce)
                    more = input("Do you want to add more? Y/N")
                    if more == 'Y':
                        continue
                    else:
                        x = False
                else: 
                    print("Invalid Input")
            
    
            order_dt = pd.DataFrame()
            for i in total_order:
                tmp = data[ data['Name'] == i ]
                order_dt = pd.concat([order_dt,tmp])
            
            return order_dt

# %%
calculate()
# Out:
# CHOOSE:
#  1. Sandwich
#  2. Salad
#  3. Wrap
#  4. Snacks
# Enter Number: 1
#
# <Which Sandwich do you want?>
#
# =====Here's the Menu=====
#
#
# ------------------------------
#  - BBQ Rib
#  - Black Forest Ham
#  - Chicken & Bacon Ranch Melt
#  - Chicken Mango Curry
#  - Chicken Tikka
#  - Chicken Vindaloo
#  - Classic Tuna
#  - Cold Cut Combo
#  - Genoa Salami
#  - Italian B.M.T.Â®
#  - Meatball Marinara
#  - Ham & Jack Slider
#  - Italian Spice Slider
#  - Little Cheesesteak Slider
#  - Little Turkey Slider
#  - Southwest Chicken Club
#  - Steak Club
#  - Ultimate Steak
#  - Oven Roasted Chicken
#  - Paneer Tikka
#  - Roast Beef
#  - Rotisserie-Style Chicken
#  - Spicy Italian
#  - Steak & Cheese
#  - Subway ClubÂ®
#  - Sweet Onion Chicken Teriyaki
#  - Turkey & Bacon Guacamole
#  - Turkey Breast
#  - Ultimate Meatball Marinara
#  - Ultimate Spicy Italian
#  - Veggie DeliteÂ®
#  ------------------------------
#
# Enter your choice of MenuTurkey Breast
# What bread do you want?
#
# ------------------------------
#  - Roasted Garlic
#  - 9-Grain Honey Oat
#  - 9-Grain Wheat
#  - Artisan Flatbread
#  - Hearty Italian**
#  - Italian
#  - Italian Herbs & Cheese
#  - JalapeÃ±o Cheese
#  - Mini 9-Grain Wheat
#  - Mini Italian
#  - Monterey Cheddar**
#  - Parmesan Oregano**
#  - Rosemary & Sea Salt
#  - Spinach Wrap
#  - Tomato Basil Wrap
#  ------------------------------
#
# Enter your choice of BreadItalian
# What cheese do you want?
# ------------------------------
#  - American
#  - Cheddar**
#  - Monterey Cheddar
#  - Pepperjack**
#  - Provolone
#  - Shredded Mozzarella
#  - Swiss**
#  ------------------------------
#
# Enter your choice of CheeseAmerican
# What veggies do you want?
#
# Choose Your Vegies from Below
#
# ------------------------------
#  - Banana Peppers
#  - Black Olives
#  - Cucumbers
#  - Green Peppers
#  - Jalapenos
#  - Lettuce
#  - Pickles
#  - Red Onions
#  - Spinach
#  - Tomatoes
#  ------------------------------
#
# Enter your choice of veggie (Choose 1)Cucumbers
# Do you want to add more? Y/NN
#
#  What sauces do you want?
#
# Choose Your Sauce from Below:
#
# ------------------------------
#  - Chipotle Southwest - Honey Mustard** - Light Mayonnaise - Oil - Ranch - Red Wine Vinegar - Regular Mayonnaise - Savory Caesar** - Spicy Brown Mustard - SubwayÂ® Vinaigrette - Sweet Onion Sauce - Yellow Mustard ------------------------------
#
# Enter your choice of sauce (Choose 1)Chipotle Southwest
# Do you want to add more? Y/NN
#                    Name  Category  Calories  Total Fat (g)  Saturated Fat (g)  \
# 27        Turkey Breast  Sandwich       250            3.0                0.5
# 47        Turkey Breast     Salad       110            2.0                0.0
# 83        Turkey Breast      Wrap       430           10.0                3.5
# 91              Italian     Bread       180            2.0                0.0
# 101            American    Cheese        40            3.5                2.0
# 125           Cucumbers   Veggies         0            0.0                0.0
# 111  Chipotle Southwest    Sauces        60            7.0                1.0
#
#      Trans Fat (g)  Cholesterol (mg)  Sodium (mg)  Carbohydrates (g)  \
# 27             0.0                30          690                 41
# 47             0.0                30          520                 11
# 83             0.0                55         1680                 56
# 91             0.0                 0          310                 34
# 101            0.0                10          210                  1
# 125            0.0                 0            0                  1
# 111            0.0                 5          110                  1
#
#      Dietary Fiber (g)  Sugars (g)  Protein (g)
# 27                   5           6           20
# 47                   4           5           14
# 83                   3           3           32
# 91                   1           3            6
# 101                  0           0            2
# 125                  0           0            0
# 111                  0           1            0
